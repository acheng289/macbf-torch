# %%
from scene import Scene

# %%
train_scene = Scene("../data/three_agents_obs_track_easy_forest_1")
# Out:
# Initializing scene using states in ../data/three_agents_obs_track_easy_forest_1
# Found ../data/three_agents_obs_track_easy_forest_1/NX02.csv, processing...
# Processed NX02, kept 2380 states after removing hover states from original 5848
# Found ../data/three_agents_obs_track_easy_forest_1/NX03.csv, processing...
# Processed NX03, kept 2026 states after removing hover states from original 5844
# Found ../data/three_agents_obs_track_easy_forest_1/NX01.csv, processing...
# Processed NX01, kept 2416 states after removing hover states from original 5850
# Padded agent NX02 from 2380 to 2416 timesteps.
# Padded agent NX03 from 2026 to 2416 timesteps.
# Final scene states shape: (2416, 3, 10) (TxNxS)

# %%
train_scene.visualize_scene()

# %%
eval_scene = Scene("../eval/three_agents_obs_track_easy_forest_1_evaluated")
# Out:
# Initializing scene using states in ../eval/three_agents_obs_track_easy_forest_1_evaluated
# Found ../eval/three_agents_obs_track_easy_forest_1_evaluated/NX02.csv, processing...
# Processed NX02, kept 2381 states after removing hover states from original 2416
# Found ../eval/three_agents_obs_track_easy_forest_1_evaluated/NX03.csv, processing...
# Processed NX03, kept 2027 states after removing hover states from original 2416
# Found ../eval/three_agents_obs_track_easy_forest_1_evaluated/NX01.csv, processing...
# Processed NX01, kept 2416 states after removing hover states from original 2416
# Padded agent NX02 from 2381 to 2416 timesteps.
# Padded agent NX03 from 2027 to 2416 timesteps.
# Final scene states shape: (2416, 3, 10) (TxNxS)

# %%
eval_scene.visualize_scene()

# %%
train_scene.get_state(0)
# Out:
# array([[ 0., -5.,  3.,  0.,  0.,  0.,  0.,  0.,  0.,  1.],
#        [ 0.,  5.,  3.,  0.,  0.,  0.,  0.,  0.,  0.,  1.],
#        [ 0.,  0.,  3.,  0.,  0.,  0.,  0.,  0.,  0.,  1.]])

# %%
eval_scene.get_state(0)
# Out:
# array([[ 0., -5.,  3.,  0.,  0.,  0.,  0.,  0.,  0.,  1.],
#        [ 0.,  5.,  3.,  0.,  0.,  0.,  0.,  0.,  0.,  1.],
#        [ 0.,  0.,  3.,  0.,  0.,  0.,  0.,  0.,  0.,  1.]])

# %%
train_scene.get_state(2)
# Out:
# array([[ 1.110000e-04, -5.000014e+00,  2.999999e+00,  1.107300e-02,
#         -1.384000e-03, -1.200000e-04,  4.134000e-03,  3.764100e-02,
#         -1.498900e-02,  9.991700e-01],
#        [ 3.500000e-05,  4.999965e+00,  2.999996e+00,  5.308000e-03,
#         -5.300000e-03, -5.890000e-04,  2.684300e-02,  2.742800e-02,
#         -9.992000e-03,  9.992130e-01],
#        [ 2.390000e-04, -1.000000e-06,  2.999995e+00,  1.792200e-02,
#         -1.040000e-04, -3.410000e-04,  2.590000e-04,  4.560900e-02,
#         -1.160000e-04,  9.989590e-01]])

# %%
eval_scene.get_state(2)
# Out:
# array([[-6.5650890e-04, -5.0002750e+00,  3.0008442e+00,  1.1622073e-02,
#         -1.2306091e-03, -6.9563580e-05,  2.7111627e-03,  3.7841506e-02,
#         -1.5757380e-02,  1.0000800e+00],
#        [-7.3268860e-04,  4.9997040e+00,  3.0008402e+00,  5.8576083e-03,
#         -5.1457356e-03, -5.3911470e-04,  2.5419400e-02,  2.7628655e-02,
#         -1.0760522e-02,  1.0001234e+00],
#        [-5.2891060e-04, -2.6194926e-04,  3.0008410e+00,  1.8470816e-02,
#          4.9118156e-05, -2.9025170e-04, -1.1641377e-03,  4.5809265e-02,
#         -8.8417693e-04,  9.9986917e-01]])
